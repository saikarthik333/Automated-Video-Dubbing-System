# %% [markdown]
# <a href="https://colab.research.google.com/github/saikarthik333/Automated-Video-Dubbing-System/blob/main/Automated_Video_Dubbing_System.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Wed Jul 22 05:12:07 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   53C    P8             10W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !ls /content/
# Out:
# drive	 pipeline   requirements.txt  test.mp3
# main.py  README.md  sample_data       test_tts.py

# %%
# !pwd
# Out:
# /content

# %%
# !pip install -r requirements.txt -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.8/183.8 kB 7.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 76.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 74.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.5/35.5 MB 59.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.5/39.5 MB 26.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.7/18.7 MB 81.3 MB/s eta 0:00:00

# %%
import torch
print(torch.cuda.is_available(), torch.cuda.get_device_name(0))
# Out:
# True Tesla T4

# %%
# !python main.py "https://youtube.com/shorts/BUbC1xx7Jfw?si=qLvvcozBrhIioA0F" --whisper-model medium --device cpu --language hi
# Out:
# /usr/local/lib/python3.12/dist-packages/pydub/utils.py:300: SyntaxWarning: invalid escape sequence '\('
#   m = re.match('([su]([0-9]{1,2})p?) \(([0-9]{1,2}) bit\)$', token)
# /usr/local/lib/python3.12/dist-packages/pydub/utils.py:301: SyntaxWarning: invalid escape sequence '\('
#   m2 = re.match('([su]([0-9]{1,2})p?)( \(default\))?$', token)
# /usr/local/lib/python3.12/dist-packages/pydub/utils.py:310: SyntaxWarning: invalid escape sequence '\('
#   elif re.match('(flt)p?( \(default\))?$', token):
# /usr/local/lib/python3.12/dist-packages/pydub/utils.py:314: SyntaxWarning: invalid escape sequence '\('
#   elif re.match('(dbl)p?( \(default\))?$', token):
# [   14.6s] PIPELINE     Starting dub job for https://youtube.com/shorts/BUbC1xx7Jfw?si=qLvvcozBrhIioA0F
# [   14.6s] DOWNLOAD     Fetching info for https://youtube.com/shorts/BUbC1xx7Jfw?si=qLvvcozBrhIioA0F
# [   17.6s] DOWNLOAD     Done: 'Hindi Podcast Video #youtubeshorts #shortvideo' (0 min) -> output/source.mp4
# ...

# %%
# !python main.py "https://youtube.com/shorts/BUbC1xx7Jfw?si=qLvvcozBrhIioA0F" --whisper-model large-v3 --device cuda --language hi
# Out:
# [   11.6s] PIPELINE     Starting dub job for https://youtube.com/shorts/BUbC1xx7Jfw?si=qLvvcozBrhIioA0F
# [   11.6s] DOWNLOAD     Fetching info for https://youtube.com/shorts/BUbC1xx7Jfw?si=qLvvcozBrhIioA0F
# [   13.0s] DOWNLOAD     Done: 'Hindi Podcast Video #youtubeshorts #shortvideo' (0 min) -> output/source.mp4
# [   13.0s] TRANSCRIBE   Loading Whisper model 'large-v3' on cuda
# ...
# [   56.5s] TRANSCRIBE   Running speech recognition (this can take a while)...
# [   62.0s] TRANSCRIBE   [0:00:00.000 -> 0:00:03.700] उसी तरह रवी शास्त्री और कोली as a unit कैसे थे?
# [   62.0s] TRANSCRIBE   [0:00:03.960 -> 0:00:04.840] मतलब आपके नजरिये से
# [   62.0s] TRANSCRIBE   [0:00:04.840 -> 0:00:08.500] र वीशा स्ट्रि औ आ पने सुना होगा ये की
# [   62.0s] TRANSCRIBE   [0:00:08.500 -> 0:00:11.370] some people say and I agree की
# [   62.0s] TRANSCRIBE   [0:00:11.370 -> 0:00:13.870] he should have been captain of India for a longer time
# ...

# %%
# !python main.py "https://youtu.be/9yCqE-uE6HE?si=FZD9rfizUivC2vG1" --whisper-model large-v3 --device cuda --language hi
# Out:
# [   12.7s] PIPELINE     Starting dub job for https://youtu.be/9yCqE-uE6HE?si=FZD9rfizUivC2vG1
# [   12.7s] DOWNLOAD     Fetching info for https://youtu.be/9yCqE-uE6HE?si=FZD9rfizUivC2vG1
# [   14.3s] DOWNLOAD     Done: 'TOP 10 Rules To Become SUCCESSFUL In Life ft @anantladhaofficial @LabourLawAdvisor -FO42| Raj Shamani' (37 min) -> output/source.mp4
# [   14.3s] TRANSCRIBE   Loading Whisper model 'large-v3' on cuda
# [   23.5s] TRANSCRIBE   Running speech recognition (this can take a while)...
# [   28.6s] TRANSCRIBE   [0:00:00.000 -> 0:00:03.700] उसी तरह रवी शास्त्री और कोली as a unit कैसे थे?
# [   28.6s] TRANSCRIBE   [0:00:03.960 -> 0:00:04.840] मतलब आपके नजरिये से
# [   28.6s] TRANSCRIBE   [0:00:04.840 -> 0:00:08.500] र वीशा स्ट्रि औ आ पने सुना होगा ये की
# [   28.6s] TRANSCRIBE   [0:00:08.500 -> 0:00:11.370] some people say and I agree की
# [   28.6s] TRANSCRIBE   [0:00:11.370 -> 0:00:13.870] he should have been captain of India for a longer time
# ...

# %%
# !rm -rf output

# %%
# !python main.py "https://youtu.be/9yCqE-uE6HE?si=FZD9rfizUivC2vG1" --whisper-model large-v3 --device cuda --language hi
# Out:
# [   11.8s] PIPELINE     Starting dub job for https://youtu.be/9yCqE-uE6HE?si=FZD9rfizUivC2vG1
# [   11.8s] DOWNLOAD     Fetching info for https://youtu.be/9yCqE-uE6HE?si=FZD9rfizUivC2vG1
# [   39.3s] DOWNLOAD     Done: 'TOP 10 Rules To Become SUCCESSFUL In Life ft @anantladhaofficial @LabourLawAdvisor -FO42| Raj Shamani' (37 min) -> output/source.mp4
# [   39.3s] TRANSCRIBE   Loading Whisper model 'large-v3' on cuda
# [   47.2s] TRANSCRIBE   Running speech recognition (this can take a while)...
# [   76.3s] TRANSCRIBE   [0:00:00.000 -> 0:00:01.600] सक्सेसफल बनने के लिए क्या होना चाहिई?
# [   76.3s] TRANSCRIBE   [0:00:01.920 -> 0:00:04.580] बहुत पैसा, बہुट इंटेलिजन्स,
# [   76.3s] TRANSCRIBE   [0:00:04.820 -> 0:00:05.920] बahut लोगों का नेटवर्क,
# [   76.3s] TRANSCRIBE   [0:00:06.320 -> 0:00:07.220] की बाहूत सारी फ़ंडिंग,
# [   76.3s] TRANSCRIBE   [0:00:07.300 -> 0:00:08.160] क्षा बोहत क्रेजी आइडेया,
# [   76.3s] TRANSCRIBE   [0:00:08.440 -> 0:00:08.720] नहीं.
# ...

# %%
# !mkdir -p "/content/drive/MyDrive/video_dubbing_output"
# !cp output/dubbed_output.mp4 "/content/drive/MyDrive/video_dubbing_output/"

# %%
# !rm -rf output

# %%
# !python main.py "https://youtu.be/6jBaJkwfL1s?si=bmoP-rBIauORQbgg" --whisper-model large-v3 --device cuda --language hi --output-dir "/content/drive/MyDrive/video_dubbing_output2/run1"
# Out:
# Streaming output truncated to the last 5000 lines.
# [ 1383.0s] TRANSLATE    (980/2984) '5 years from now, 10 years from' -> '5 years from now, 10 years from now'
# [ 1383.3s] TRANSLATE    (981/2984) "now, you may say what's the point" -> "now, you may say what's the point"
# [ 1383.6s] TRANSLATE    (982/2984) "in knowing that, if there's no treatment" -> 'in knowing that, if there is no treatment'
# [ 1384.2s] TRANSLATE    (983/2984) 'The good news is that just like the GLP drugs we have 80 different molecules coming' -> 'The good news is that just like the GLP drugs, we have 80 different molecules coming in.'
# [ 1384.6s] TRANSLATE    (984/2984) 'There are at least 10 different dementia drugs which are coming' -> 'There are at least 10 different dementia drugs that are coming.'
# [ 1384.9s] TRANSLATE    (985/2984) 'They are in phase 2, phase 3' -> 'They are in phase 2, phase 3.'
# ...
